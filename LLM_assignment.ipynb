# %% [markdown]
# * Run the code below to install the dependencies

# %%
# Install bitsandbytes et transformers
# !pip install bitsandbytes
# !pip install transformers datasets huggingface_hub

# Install auto-gptq
# !pip install auto-gptq
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (2.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 12.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.44.1
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (0.25.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: accelerate>=0.26.0 in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (0.34.2)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (3.0.1)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (0.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (1.26.4)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (2.4.0)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (0.4.5)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (4.45.1)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.13.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (4.66.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (0.25.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (2024.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (0.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (2.2.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (3.9.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate>=0.26.0->auto-gptq) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 54.1 MB/s eta 0:00:00:00:0100:01
# Downloading peft-0.13.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 20.8 MB/s eta 0:00:00
# Downloading gekko-1.2.1-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 87.0 MB/s eta 0:00:00:00:01:01m
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge, gekko, peft, auto-gptq
# Successfully installed auto-gptq-0.7.1 gekko-1.2.1 peft-0.13.2 rouge-1.0.1

# %% [markdown]
# * Run the code below and make sure the CUDA GPU is available

# %%
# Imports libraries
from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from auto_gptq import AutoGPTQForCausalLM, BaseQuantizeConfig
import bitsandbytes as bnb 
from huggingface_hub import login
import numpy as np
import torch
import random
import time
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:64"

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

# Use of GPU or CPU
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU CUDA available")
else:
    device = torch.device("cpu")
    print("No GPU CUDA available, CPU used")

# Access to Hugging Face
access_token=user_secrets.get_secret("HF_TOKEN")
login(token=access_token)
# Out:
# GPU CUDA available
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# * Run the code below to quantize the model
# * To choose the number of bits to quantify, just change the number between brackets in the For loop

# %%
# Llama Loading
print('Llama loading...')
model_name = "meta-llama/Llama-3.2-3B"
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=access_token, use_fast=True, trust_remote_code=True)
print('Llama loaded !')

# Quantization
def quantization (model_name, bits):
    torch.cuda.empty_cache()
    print("Model quantization ...")
    quantize_config = BaseQuantizeConfig(bits=bits, group_size=64, desc_act=False)
    model = AutoGPTQForCausalLM.from_pretrained(
        model_name,
        quantize_config=quantize_config,
        use_flash_attention_2=False,
        low_cpu_mem_usage=True,
        use_cache=False
    )
    model.to(device)
    examples = [
        tokenizer(
            "auto-gptq is an easy-to-use model quantization library with user-friendly apis, based on GPTQ algorithm."
        )
    ]
    model.quantize(examples, batch_size=1)
    save_dir = f"/kaggle/working/quantized_model/{bits}bit_quantized"
    model.save_quantized(save_dir)
    print('Model quantized !')
    

for bits in [8]: # Put the number of bits between squared brackets to quantify
    print(f"{bits} bits quantization ...")
    torch.cuda.empty_cache()
    quantization(model_name, bits)
    print(f"{bits} bits quantization finished !")
# Out:
# Llama loading...
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:796: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Llama loaded !
# 8 bits quantization ...
# Model quantization ...
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# INFO - Start quantizing layer 1/28
# INFO - Quantizing self_attn.k_proj in layer 1/28...
# INFO - Quantizing self_attn.v_proj in layer 1/28...
# INFO - Quantizing self_attn.q_proj in layer 1/28...
# INFO - Quantizing self_attn.o_proj in layer 1/28...
# INFO - Quantizing mlp.up_proj in layer 1/28...
# INFO - Quantizing mlp.gate_proj in layer 1/28...
# INFO - Quantizing mlp.down_proj in layer 1/28...
# INFO - Start quantizing layer 2/28
# INFO - Quantizing self_attn.k_proj in layer 2/28...
# INFO - Quantizing self_attn.v_proj in layer 2/28...
# INFO - Quantizing self_attn.q_proj in layer 2/28...
# INFO - Quantizing self_attn.o_proj in layer 2/28...
# INFO - Quantizing mlp.up_proj in layer 2/28...
# INFO - Quantizing mlp.gate_proj in layer 2/28...
# INFO - Quantizing mlp.down_proj in layer 2/28...
# INFO - Start quantizing layer 3/28
# INFO - Quantizing self_attn.k_proj in layer 3/28...
# INFO - Quantizing self_attn.v_proj in layer 3/28...
# INFO - Quantizing self_attn.q_proj in layer 3/28...
# INFO - Quantizing self_attn.o_proj in layer 3/28...
# INFO - Quantizing mlp.up_proj in layer 3/28...
# INFO - Quantizing mlp.gate_proj in layer 3/28...
# INFO - Quantizing mlp.down_proj in layer 3/28...
# INFO - Start quantizing layer 4/28
# INFO - Quantizing self_attn.k_proj in layer 4/28...
# INFO - Quantizing self_attn.v_proj in layer 4/28...
# INFO - Quantizing self_attn.q_proj in layer 4/28...
# INFO - Quantizing self_attn.o_proj in layer 4/28...
# INFO - Quantizing mlp.up_proj in layer 4/28...
# INFO - Quantizing mlp.gate_proj in layer 4/28...
# INFO - Quantizing mlp.down_proj in layer 4/28...
# INFO - Start quantizing layer 5/28
# INFO - Quantizing self_attn.k_proj in layer 5/28...
# INFO - Quantizing self_attn.v_proj in layer 5/28...
# INFO - Quantizing self_attn.q_proj in layer 5/28...
# INFO - Quantizing self_attn.o_proj in layer 5/28...
# INFO - Quantizing mlp.up_proj in layer 5/28...
# INFO - Quantizing mlp.gate_proj in layer 5/28...
# INFO - Quantizing mlp.down_proj in layer 5/28...
# INFO - Start quantizing layer 6/28
# INFO - Quantizing self_attn.k_proj in layer 6/28...
# INFO - Quantizing self_attn.v_proj in layer 6/28...
# INFO - Quantizing self_attn.q_proj in layer 6/28...
# INFO - Quantizing self_attn.o_proj in layer 6/28...
# INFO - Quantizing mlp.up_proj in layer 6/28...
# INFO - Quantizing mlp.gate_proj in layer 6/28...
# INFO - Quantizing mlp.down_proj in layer 6/28...
# INFO - Start quantizing layer 7/28
# INFO - Quantizing self_attn.k_proj in layer 7/28...
# INFO - Quantizing self_attn.v_proj in layer 7/28...
# INFO - Quantizing self_attn.q_proj in layer 7/28...
# INFO - Quantizing self_attn.o_proj in layer 7/28...
# INFO - Quantizing mlp.up_proj in layer 7/28...
# INFO - Quantizing mlp.gate_proj in layer 7/28...
# INFO - Quantizing mlp.down_proj in layer 7/28...
# INFO - Start quantizing layer 8/28
# INFO - Quantizing self_attn.k_proj in layer 8/28...
# INFO - Quantizing self_attn.v_proj in layer 8/28...
# INFO - Quantizing self_attn.q_proj in layer 8/28...
# INFO - Quantizing self_attn.o_proj in layer 8/28...
# INFO - Quantizing mlp.up_proj in layer 8/28...
# INFO - Quantizing mlp.gate_proj in layer 8/28...
# INFO - Quantizing mlp.down_proj in layer 8/28...
# INFO - Start quantizing layer 9/28
# INFO - Quantizing self_attn.k_proj in layer 9/28...
# INFO - Quantizing self_attn.v_proj in layer 9/28...
# INFO - Quantizing self_attn.q_proj in layer 9/28...
# INFO - Quantizing self_attn.o_proj in layer 9/28...
# INFO - Quantizing mlp.up_proj in layer 9/28...
# INFO - Quantizing mlp.gate_proj in layer 9/28...
# INFO - Quantizing mlp.down_proj in layer 9/28...
# INFO - Start quantizing layer 10/28
# INFO - Quantizing self_attn.k_proj in layer 10/28...
# INFO - Quantizing self_attn.v_proj in layer 10/28...
# INFO - Quantizing self_attn.q_proj in layer 10/28...
# INFO - Quantizing self_attn.o_proj in layer 10/28...
# INFO - Quantizing mlp.up_proj in layer 10/28...
# INFO - Quantizing mlp.gate_proj in layer 10/28...
# INFO - Quantizing mlp.down_proj in layer 10/28...
# INFO - Start quantizing layer 11/28
# INFO - Quantizing self_attn.k_proj in layer 11/28...
# INFO - Quantizing self_attn.v_proj in layer 11/28...
# INFO - Quantizing self_attn.q_proj in layer 11/28...
# INFO - Quantizing self_attn.o_proj in layer 11/28...
# INFO - Quantizing mlp.up_proj in layer 11/28...
# INFO - Quantizing mlp.gate_proj in layer 11/28...
# INFO - Quantizing mlp.down_proj in layer 11/28...
# INFO - Start quantizing layer 12/28
# INFO - Quantizing self_attn.k_proj in layer 12/28...
# INFO - Quantizing self_attn.v_proj in layer 12/28...
# INFO - Quantizing self_attn.q_proj in layer 12/28...
# INFO - Quantizing self_attn.o_proj in layer 12/28...
# INFO - Quantizing mlp.up_proj in layer 12/28...
# INFO - Quantizing mlp.gate_proj in layer 12/28...
# INFO - Quantizing mlp.down_proj in layer 12/28...
# INFO - Start quantizing layer 13/28
# INFO - Quantizing self_attn.k_proj in layer 13/28...
# INFO - Quantizing self_attn.v_proj in layer 13/28...
# INFO - Quantizing self_attn.q_proj in layer 13/28...
# INFO - Quantizing self_attn.o_proj in layer 13/28...
# INFO - Quantizing mlp.up_proj in layer 13/28...
# INFO - Quantizing mlp.gate_proj in layer 13/28...
# INFO - Quantizing mlp.down_proj in layer 13/28...
# INFO - Start quantizing layer 14/28
# INFO - Quantizing self_attn.k_proj in layer 14/28...
# INFO - Quantizing self_attn.v_proj in layer 14/28...
# INFO - Quantizing self_attn.q_proj in layer 14/28...
# INFO - Quantizing self_attn.o_proj in layer 14/28...
# INFO - Quantizing mlp.up_proj in layer 14/28...
# INFO - Quantizing mlp.gate_proj in layer 14/28...
# INFO - Quantizing mlp.down_proj in layer 14/28...
# INFO - Start quantizing layer 15/28
# INFO - Quantizing self_attn.k_proj in layer 15/28...
# INFO - Quantizing self_attn.v_proj in layer 15/28...
# INFO - Quantizing self_attn.q_proj in layer 15/28...
# INFO - Quantizing self_attn.o_proj in layer 15/28...
# INFO - Quantizing mlp.up_proj in layer 15/28...
# INFO - Quantizing mlp.gate_proj in layer 15/28...
# INFO - Quantizing mlp.down_proj in layer 15/28...
# INFO - Start quantizing layer 16/28
# INFO - Quantizing self_attn.k_proj in layer 16/28...
# INFO - Quantizing self_attn.v_proj in layer 16/28...
# INFO - Quantizing self_attn.q_proj in layer 16/28...
# INFO - Quantizing self_attn.o_proj in layer 16/28...
# INFO - Quantizing mlp.up_proj in layer 16/28...
# INFO - Quantizing mlp.gate_proj in layer 16/28...
# INFO - Quantizing mlp.down_proj in layer 16/28...
# INFO - Start quantizing layer 17/28
# INFO - Quantizing self_attn.k_proj in layer 17/28...
# INFO - Quantizing self_attn.v_proj in layer 17/28...
# INFO - Quantizing self_attn.q_proj in layer 17/28...
# INFO - Quantizing self_attn.o_proj in layer 17/28...
# INFO - Quantizing mlp.up_proj in layer 17/28...
# INFO - Quantizing mlp.gate_proj in layer 17/28...
# INFO - Quantizing mlp.down_proj in layer 17/28...
# INFO - Start quantizing layer 18/28
# INFO - Quantizing self_attn.k_proj in layer 18/28...
# INFO - Quantizing self_attn.v_proj in layer 18/28...
# INFO - Quantizing self_attn.q_proj in layer 18/28...
# INFO - Quantizing self_attn.o_proj in layer 18/28...
# INFO - Quantizing mlp.up_proj in layer 18/28...
# INFO - Quantizing mlp.gate_proj in layer 18/28...
# INFO - Quantizing mlp.down_proj in layer 18/28...
# INFO - Start quantizing layer 19/28
# INFO - Quantizing self_attn.k_proj in layer 19/28...
# INFO - Quantizing self_attn.v_proj in layer 19/28...
# INFO - Quantizing self_attn.q_proj in layer 19/28...
# INFO - Quantizing self_attn.o_proj in layer 19/28...
# INFO - Quantizing mlp.up_proj in layer 19/28...
# INFO - Quantizing mlp.gate_proj in layer 19/28...
# INFO - Quantizing mlp.down_proj in layer 19/28...
# INFO - Start quantizing layer 20/28
# INFO - Quantizing self_attn.k_proj in layer 20/28...
# INFO - Quantizing self_attn.v_proj in layer 20/28...
# INFO - Quantizing self_attn.q_proj in layer 20/28...
# INFO - Quantizing self_attn.o_proj in layer 20/28...
# INFO - Quantizing mlp.up_proj in layer 20/28...
# INFO - Quantizing mlp.gate_proj in layer 20/28...
# INFO - Quantizing mlp.down_proj in layer 20/28...
# INFO - Start quantizing layer 21/28
# INFO - Quantizing self_attn.k_proj in layer 21/28...
# INFO - Quantizing self_attn.v_proj in layer 21/28...
# INFO - Quantizing self_attn.q_proj in layer 21/28...
# INFO - Quantizing self_attn.o_proj in layer 21/28...
# INFO - Quantizing mlp.up_proj in layer 21/28...
# INFO - Quantizing mlp.gate_proj in layer 21/28...
# INFO - Quantizing mlp.down_proj in layer 21/28...
# INFO - Start quantizing layer 22/28
# INFO - Quantizing self_attn.k_proj in layer 22/28...
# INFO - Quantizing self_attn.v_proj in layer 22/28...
# INFO - Quantizing self_attn.q_proj in layer 22/28...
# INFO - Quantizing self_attn.o_proj in layer 22/28...
# INFO - Quantizing mlp.up_proj in layer 22/28...
# INFO - Quantizing mlp.gate_proj in layer 22/28...
# INFO - Quantizing mlp.down_proj in layer 22/28...
# INFO - Start quantizing layer 23/28
# INFO - Quantizing self_attn.k_proj in layer 23/28...
# INFO - Quantizing self_attn.v_proj in layer 23/28...
# INFO - Quantizing self_attn.q_proj in layer 23/28...
# INFO - Quantizing self_attn.o_proj in layer 23/28...
# INFO - Quantizing mlp.up_proj in layer 23/28...
# INFO - Quantizing mlp.gate_proj in layer 23/28...
# INFO - Quantizing mlp.down_proj in layer 23/28...
# INFO - Start quantizing layer 24/28
# INFO - Quantizing self_attn.k_proj in layer 24/28...
# INFO - Quantizing self_attn.v_proj in layer 24/28...
# INFO - Quantizing self_attn.q_proj in layer 24/28...
# INFO - Quantizing self_attn.o_proj in layer 24/28...
# INFO - Quantizing mlp.up_proj in layer 24/28...
# INFO - Quantizing mlp.gate_proj in layer 24/28...
# INFO - Quantizing mlp.down_proj in layer 24/28...
# INFO - Start quantizing layer 25/28
# INFO - Quantizing self_attn.k_proj in layer 25/28...
# INFO - Quantizing self_attn.v_proj in layer 25/28...
# INFO - Quantizing self_attn.q_proj in layer 25/28...
# INFO - Quantizing self_attn.o_proj in layer 25/28...
# INFO - Quantizing mlp.up_proj in layer 25/28...
# INFO - Quantizing mlp.gate_proj in layer 25/28...
# INFO - Quantizing mlp.down_proj in layer 25/28...
# INFO - Start quantizing layer 26/28
# INFO - Quantizing self_attn.k_proj in layer 26/28...
# INFO - Quantizing self_attn.v_proj in layer 26/28...
# INFO - Quantizing self_attn.q_proj in layer 26/28...
# INFO - Quantizing self_attn.o_proj in layer 26/28...
# INFO - Quantizing mlp.up_proj in layer 26/28...
# INFO - Quantizing mlp.gate_proj in layer 26/28...
# INFO - Quantizing mlp.down_proj in layer 26/28...
# INFO - Start quantizing layer 27/28
# INFO - Quantizing self_attn.k_proj in layer 27/28...
# INFO - Quantizing self_attn.v_proj in layer 27/28...
# INFO - Quantizing self_attn.q_proj in layer 27/28...
# INFO - Quantizing self_attn.o_proj in layer 27/28...
# INFO - Quantizing mlp.up_proj in layer 27/28...
# INFO - Quantizing mlp.gate_proj in layer 27/28...
# INFO - Quantizing mlp.down_proj in layer 27/28...
# INFO - Start quantizing layer 28/28
# INFO - Quantizing self_attn.k_proj in layer 28/28...
# INFO - Quantizing self_attn.v_proj in layer 28/28...
# INFO - Quantizing self_attn.q_proj in layer 28/28...
# INFO - Quantizing self_attn.o_proj in layer 28/28...
# INFO - Quantizing mlp.up_proj in layer 28/28...
# INFO - Quantizing mlp.gate_proj in layer 28/28...
# INFO - Quantizing mlp.down_proj in layer 28/28...
# Model quantized !
# 8 bits quantization finished !

# %% [markdown]
# * When the code above displays Quantification of the model is complete, run the code below to zip the quantified model
# * Once the code below has been run, save the notebook using the **Save Version** button at the top right of the interface
# * This step is not mandatory

# %%
# !zip -r /kaggle/working/quantized_models.zip /kaggle/working/quantized_model

# %% [markdown]
# * The code below allows you to run tests on a quantified model
# * Just replace the path where the quantified model folder is located on the Kaggle environment

# %%
# LAMBADA dataset loading
print('LAMBADA dataset loading ...')
dataset = load_dataset("lambada", split="validation")
print('LAMBADA dataset loaded !')

# Quantized model loading
accuracy_results = []
tokens_per_second_results = []
number_parameters_results = []

model = AutoGPTQForCausalLM.from_quantized('/kaggle/working/quantized_model/8bit_quantized') # Change the path here
model.to(device)

# Evaluation metrics
counter = 1
total_tokens = 0
k = 5
top_k_correct = 0
start_time = time.time()

# Model evaluation
print('Model evaluation ...')
for example in dataset:
    print("counter : " + str(counter))

    # Processing data
    sentence = example["text"]
    split_sentence = sentence.split()
    true_word = split_sentence.pop(-1)
    prompt = ' '.join(split_sentence)
        
    # Tokenisation generation
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Checking k last tokens
    top_k_tokens = torch.topk(outputs.logits[0, -1, :], k=k).indices
    predicted_words = tokenizer.batch_decode(top_k_tokens)
    print('predicted_words : ' + str(predicted_words))
    
    if true_word in [word.strip() for word in predicted_words]:
        top_k_correct += 1
    print(top_k_correct)
    
    total_tokens += inputs['input_ids'].size(1)
    print('total_tokens : ' + str(total_tokens))
    
    counter += 1
    print("time : " + str(time.time() - start_time))

print('Model evaluation finsihed !')

# Metrics computing
end_time = time.time()
accuracy_top_k = top_k_correct / len(dataset)
tokens_per_second = total_tokens / (end_time - start_time)
inference_time = counter / (end_time - start_time)
number_of_parameters = model.num_parameters()

accuracy_results.append(accuracy_top_k)
tokens_per_second_results.append(tokens_per_second)
number_parameters_results.append(number_of_parameters)

print(f"Top-{k} Accuracy: {accuracy_top_k * 100:.2f}%")
print(f"Speed: {tokens_per_second:.2f} Tokens/s")
print(f"Inference Time : {inference_time}")
print(f"Number of parameters: {number_of_parameters:.2f}")

print("Results :")
print(f"Top-{k} Accuracy: {accuracy_results}")
print(f"Speed: {tokens_per_second_results}")
print(f"Number of parameters: {number_parameters_results}")
# Out:
# LAMBADA dataset loading ...
# README.md:   0%|          | 0.00/7.32k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/269M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/281M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2662 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5153 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/4869 [00:00<?, ? examples/s]
# WARNING - Exllamav2 kernel is not installed, reset disable_exllamav2 to True. This may because you installed auto_gptq using a pre-build wheel on Windows, in which exllama_kernels are not compiled. To use exllama_kernels to further speedup inference, you can re-install auto_gptq from source.
# WARNING - CUDA kernels for auto_gptq are not installed, this will result in very slow inference speed. This may because:
# 1. You disabled CUDA extensions compilation by setting BUILD_CUDA_EXT=0 when install auto_gptq from source.
# 2. You are using pytorch without CUDA support.
# 3. CUDA and nvcc are not installed in your device.
# WARNING - ignoring unknown parameter in quantize_config.json: quant_method.
# INFO - The layer lm_head is not quantized.
# LAMBADA dataset loaded !
# Model evaluation ...
# counter : 1
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# predicted_words : [' cake', ' table', ' dessert', ' wedding', ' tower']
# 1
# total_tokens : 106
# time : 0.5491220951080322
# counter : 2
# predicted_words : [' my', " ''", ' row', ' little', ' princess']
# 1
# total_tokens : 198
# time : 0.9475893974304199
# counter : 3
# predicted_words : [' mat', ' other', ' mats', ' opposite', ' ground']
# 2
# total_tokens : 267
# time : 1.3458788394927979
# counter : 4
# predicted_words : [' a', ' an', ' trouble', ' another', ' the']
# 3
# total_tokens : 363
# time : 1.7461364269256592
# counter : 5
# predicted_words : [' children', ' arrows', ' kids', ' sons', ' two']
# 4
# total_tokens : 446
# time : 2.144033432006836
# counter : 6
# predicted_words : [' the', ' him', ' luc', ' my', ' his']
# 4
# total_tokens : 544
# time : 2.5590004920959473
# counter : 7
# predicted_words : [' fetch', ' find', ' do', ' get', ' use']
# 5
# total_tokens : 629
# time : 2.9579195976257324
# counter : 8
# predicted_words : [' ze', ' the', ' Zeus', ' z', ' god']
# 5
# total_tokens : 716
# time : 3.3554043769836426
# counter : 9
# predicted_words : [' animal', ' beast', ' wolf', ' creature', ' other']
# 6
# total_tokens : 797
# time : 3.752976894378662
# counter : 10
# predicted_words : [' famine', ' the', ' ank', ' he', ' his']
# 7
# total_tokens : 868
# time : 4.150413274765015
# counter : 11
# predicted_words : [' michael', " ''", ' boss', ' are', ' my']
# 8
# total_tokens : 947
# time : 4.548495292663574
# counter : 12
# predicted_words : [' purple', ' the', ' lil', ' a', ' these']
# 9
# total_tokens : 1015
# time : 4.945704460144043
# counter : 13
# predicted_words : [' bek', ' him', ' his', ' the', ' her']
# 9
# total_tokens : 1099
# time : 5.342676162719727
# counter : 14
# predicted_words : [' the', ' her', ' herself', ' a', ' him']
# 9
# total_tokens : 1190
# time : 5.740312576293945
# counter : 15
# predicted_words : [' handsome', ' good', ' pretty', ' beautiful', '...']
# 9
# total_tokens : 1265
# time : 6.137145280838013
# counter : 16
# predicted_words : [' k', ' i', ' but', " ''", ' and']
# 9
# total_tokens : 1329
# time : 6.510652542114258
# counter : 17
# predicted_words : [' w', ' the', ' his', ' me', ' him']
# 9
# total_tokens : 1413
# time : 6.908703565597534
# counter : 18
# predicted_words : [' ed', ' e', ' the', ' as', ' luc']
# 9
# total_tokens : 1487
# time : 7.306309938430786
# counter : 19
# predicted_words : [' l', ' the', ' her', ' me', ' their']
# 9
# total_tokens : 1571
# time : 7.704273700714111
# counter : 20
# predicted_words : [' fire', ' that', ' your', ' a', ' the']
# 10
# total_tokens : 1644
# time : 8.101779460906982
# counter : 21
# predicted_words : [" ''", ' right', ' Apollo', ' "', ' do']
# 10
# total_tokens : 1720
# time : 8.499767065048218
# counter : 22
# predicted_words : [' trouble', ' most', ' problem', ' troubles', ' problems']
# 11
# total_tokens : 1799
# time : 8.896846771240234
# counter : 23
# predicted_words : [' sprink', ' them', ' a', ' fire', ' the']
# 11
# total_tokens : 1874
# time : 9.293888568878174
# counter : 24
# predicted_words : [' anger', ' a', ' his', ' anticipation', ' excitement']
# 12
# total_tokens : 1942
# time : 9.691261529922485
# counter : 25
# predicted_words : [' krist', ' her', ' k', ' the', ' Krist']
# 12
# total_tokens : 2041
# time : 10.105728149414062
# counter : 26
# predicted_words : [' and', ' but', ' jo', " ''", ' i']
# 12
# total_tokens : 2118
# time : 10.504072666168213
# counter : 27
# predicted_words : [" ''", ' father', "''", ' Father', ' sir']
# 13
# total_tokens : 2185
# time : 10.90091848373413
# counter : 28
# predicted_words : [' packet', ' little', ' package', ' plastic', ' small']
# 14
# total_tokens : 2268
# time : 11.298769474029541
# counter : 29
# predicted_words : [' n', ' him', ' the', ' my', ' his']
# 14
# total_tokens : 2350
# time : 11.696690559387207
# counter : 30
# predicted_words : [' adam', ' the', ' he', ' ad', '.']
# 15
# total_tokens : 2425
# time : 12.093920469284058
# counter : 31
# predicted_words : [' kiss', ' crowd', ' situation', ' attention', ' kissing']
# 16
# total_tokens : 2511
# time : 12.492209196090698
# counter : 32
# predicted_words : [' tether', ' fire', ' same', ' rope', ' ring']
# 17
# total_tokens : 2618
# time : 12.907285451889038
# counter : 33
# predicted_words : [' chase', ' run', ' thrill', ' running', ' chasing']
# 18
# total_tokens : 2685
# time : 13.304906606674194
# counter : 34
# predicted_words : [' news', ' broadcast', ' radio', ' program', ' words']
# 19
# total_tokens : 2798
# time : 13.720327138900757
# counter : 35
# predicted_words : [' rug', ' rugs', ' d', ' carpet', ' old']
# 20
# total_tokens : 2886
# time : 14.118546485900879
# counter : 36
# predicted_words : [' k', ' her', ' the', ' mar', ' my']
# 20
# total_tokens : 2968
# time : 14.516417503356934
# counter : 37
# predicted_words : [' sel', ' her', ' the', ' his', ' him']
# 20
# total_tokens : 3053
# time : 14.913062334060669
# counter : 38
# predicted_words : [' bride', ' vows', ' duty', ' love', ' beloved']
# 21
# total_tokens : 3153
# time : 15.327754974365234
# counter : 39
# predicted_words : [' grandma', ' her', ' grand', ' the', ' a']
# 22
# total_tokens : 3221
# time : 15.725250005722046
# counter : 40
# predicted_words : [' over', ' dark', ' gone', ' black', ' darkness']
# 23
# total_tokens : 3289
# time : 16.121626615524292
# counter : 41
# predicted_words : [' know', ' understand', ' really', ' listen', ' trust']
# 24
# total_tokens : 3369
# time : 16.519444227218628
# counter : 42
# predicted_words : [' n', ' a', ' getting', ' making', ' just']
# 24
# total_tokens : 3466
# time : 16.933626413345337
# counter : 43
# predicted_words : ['?', ' lore', ',', ' when', '?.']
# 25
# total_tokens : 3574
# time : 17.348504781723022
# counter : 44
# predicted_words : [' or', ' if', ' mall', ' honey', " ''"]
# 25
# total_tokens : 3637
# time : 17.721297025680542
# counter : 45
# predicted_words : [' le', ' luc', ' the', ' leo', ' he']
# 25
# total_tokens : 3716
# time : 18.118510723114014
# counter : 46
# predicted_words : [' nach', ' who', ' or', ' yet', ' that']
# 25
# total_tokens : 3801
# time : 18.5160071849823
# counter : 47
# predicted_words : [' den', ' her', ' where', ' Denver', ' wherever']
# 25
# total_tokens : 3878
# time : 18.913236141204834
# counter : 48
# predicted_words : [" ''", ' cel', ' c', ' you', ' and']
# 25
# total_tokens : 3954
# time : 19.311779499053955
# counter : 49
# predicted_words : [' cher', ' the', ' ch', ' cherry', ' car']
# 25
# total_tokens : 4022
# time : 19.708935976028442
# counter : 50
# predicted_words : [' chase', ' je', ' ch', ' him', ' the']
# 26
# total_tokens : 4106
# time : 20.10661244392395
# counter : 51
# predicted_words : [' pad', ' drawing', ' paper', ' legal', ' yellow']
# 27
# total_tokens : 4178
# time : 20.503498077392578
# counter : 52
# predicted_words : [' foot', ' soup', ' clock', ' window', ' table']
# 27
# total_tokens : 4251
# time : 20.900397777557373
# counter : 53
# predicted_words : [' hug', ' if', ' now', ' h', ' the']
# 27
# total_tokens : 4321
# time : 21.29766011238098
# counter : 54
# predicted_words : [' marg', ' gar', ' i', ' em', ' m']
# 27
# total_tokens : 4391
# time : 21.69525957107544
# counter : 55
# predicted_words : [' a', ' pain', ' any', ' blood', ' an']
# 28
# total_tokens : 4457
# time : 22.091742515563965
# counter : 56
# predicted_words : [' table', ' cloth', ' surface', ' linen', ',']
# 28
# total_tokens : 4536
# time : 22.488778591156006
# counter : 57
# predicted_words : [' king', ' kings', ' one', ' god', ' royal']
# 29
# total_tokens : 4619
# time : 22.885594844818115
# counter : 58
# predicted_words : [' the', ' over', ' her', ' j', ' win']
# 29
# total_tokens : 4698
# time : 23.283655643463135
# counter : 59
# predicted_words : [' chase', ' him', ' someone', ' the', ' ch']
# 30
# total_tokens : 4778
# time : 23.68224263191223
# counter : 60
# predicted_words : ['?', ' guy', " '", ' girl', ' little']
# 30
# total_tokens : 4856
# time : 24.07987117767334
# counter : 61
# predicted_words : [' pillow', ' soft', ' quilt', ' white', ' extra']
# 31
# total_tokens : 4938
# time : 24.47756290435791
# counter : 62
# predicted_words : [' her', ' the', ' mar', ' you', ' all']
# 31
# total_tokens : 5008
# time : 24.874557971954346
# counter : 63
# predicted_words : [' drink', ' have', ' be', ' get', ' go']
# 32
# total_tokens : 5085
# time : 25.27208423614502
# counter : 64
# predicted_words : [' robert', ' hack', ' the', ' ro', ' rob']
# 33
# total_tokens : 5183
# time : 25.686506748199463
# counter : 65
# predicted_words : [' dis', ' b', ' the', ' a', ' she']
# 33
# total_tokens : 5260
# time : 26.083900451660156
# counter : 66
# predicted_words : [' studying', ' spending', ' doing', ' sharing', ' living']
# 34
# total_tokens : 5339
# time : 26.48158860206604
# counter : 67
# predicted_words : [' philosopher', ' good', ' great', ' wise', ' thinker']
# 35
# total_tokens : 5412
# time : 26.87857437133789
# counter : 68
# predicted_words : ['.', ',', ' in', ' though', ' on']
# 36
# total_tokens : 5491
# time : 27.276540517807007
# counter : 69
# predicted_words : [' be', ' her', ' my', ' Be', ' me']
# 36
# total_tokens : 5561
# time : 27.67361283302307
# counter : 70
# predicted_words : [' fel', ' Fel', ' f', ' the', ' happiness']
# 36
# total_tokens : 5648
# time : 28.072381496429443
# counter : 71
# predicted_words : [' sand', ' sands', ' ground', ' d', ' desert']
# 37
# total_tokens : 5727
# time : 28.470621347427368
# counter : 72
# predicted_words : [' do', ' listen', ' follow', ' be', ' bow']
# 37
# total_tokens : 5808
# time : 28.868361473083496
# counter : 73
# predicted_words : [' girls', ' two', ' other', ' others', ' three']
# 38
# total_tokens : 5882
# time : 29.266246795654297
# counter : 74
# predicted_words : [' ships', ' torch', ' ship', ' burning', ' other']
# 38
# total_tokens : 5984
# time : 29.681020498275757
# counter : 75
# predicted_words : [' then', ' luc', ' Lucy', " ''", ' mom']
# 38
# total_tokens : 6049
# time : 30.07757544517517
# counter : 76
# predicted_words : [' sph', ' gate', ' py', ' great', ' p']
# 38
# total_tokens : 6118
# time : 30.474820613861084
# counter : 77
# predicted_words : [' trophy', '.', ' troll', ',', ' prize']
# 39
# total_tokens : 6189
# time : 30.871846437454224
# counter : 78
# predicted_words : [' bag', ' the', ' Bag', ' b', ' g']
# 39
# total_tokens : 6266
# time : 31.270087718963623
# counter : 79
# predicted_words : [' egg', ' eggs', ' baby', ' rest', ' thing']
# 40
# total_tokens : 6340
# time : 31.66770339012146
# counter : 80
# predicted_words : [' z', ' and', ' i', ' you', ' so']
# 40
# total_tokens : 6441
# time : 32.08252263069153
# counter : 81
# predicted_words : [' armour', ' door', ' stairs', ' other', ' arm']
# 40
# total_tokens : 6541
# time : 32.49747109413147
# counter : 82
# predicted_words : [' that', ' blowing', ' it', ' on', ' up']
# 41
# total_tokens : 6612
# time : 32.894484758377075
# counter : 83
# predicted_words : [' body', ' part', ' particular', ' bul', ' shape']
# 42
# total_tokens : 6694
# time : 33.293473958969116
# counter : 84
# predicted_words : [' baby', ' good', ' happy', ' blessing', ' crying']
# 43
# total_tokens : 6776
# time : 33.69325613975525
# counter : 85
# predicted_words : [' stone', ' rock', ' large', ' blue', ' strange']
# 44
# total_tokens : 6871
# time : 34.091898679733276
# counter : 86
# predicted_words : [' the', ' them', ' any', ' your', ' other']
# 44
# total_tokens : 6954
# time : 34.490208864212036
# counter : 87
# predicted_words : [' l', " ''", ' baby', ' my', ' ``']
# 44
# total_tokens : 7055
# time : 34.90488409996033
# counter : 88
# predicted_words : [' ear', ' two', ' holes', ' outer', ' ears']
# 45
# total_tokens : 7148
# time : 35.30304670333862
# counter : 89
# predicted_words : [' l', ' the', ' my', ' what', ' getting']
# 45
# total_tokens : 7226
# time : 35.7002010345459
# counter : 90
# predicted_words : [' me', ' mill', ' your', ' Mill', ' mom']
# 45
# total_tokens : 7303
# time : 36.09728264808655
# counter : 91
# predicted_words : [' square', ' street', ' army', ' crowd', ' alley']
# 46
# total_tokens : 7387
# time : 36.49560046195984
# counter : 92
# predicted_words : [" ''", ' i', ' r', " '", ' "']
# 46
# total_tokens : 7469
# time : 36.89328122138977
# counter : 93
# predicted_words : [' flesh', ' mind', ' body', ' desire', ' a']
# 46
# total_tokens : 7555
# time : 37.29120349884033
# counter : 94
# predicted_words : [' schedule', ' class', ' first', ' copy', ' pass']
# 47
# total_tokens : 7636
# time : 37.68845248222351
# counter : 95
# predicted_words : [' he', ' i', ' you', ',', ' then']
# 47
# total_tokens : 7705
# time : 38.084938049316406
# counter : 96
# predicted_words : [' ez', ' gab', ' the', ' honor', ' g']
# 47
# total_tokens : 7796
# time : 38.482463121414185
# counter : 97
# predicted_words : [' ben', ' the', ' a', ' Ben', ' r']
# 47
# total_tokens : 7870
# time : 38.879998207092285
# counter : 98
# predicted_words : [' sock', ' sog', ' object', ' item', ' wet']
# 48
# total_tokens : 7947
# time : 39.27803826332092
# counter : 99
# predicted_words : [' familiar', ' of', ' ring', ' fam', ' natural']
# 49
# total_tokens : 8035
# time : 39.67643332481384
# counter : 100
# predicted_words : [' skulls', ' thirteen', ' missing', ' souls', ' other']
# 50
# total_tokens : 8122
# time : 40.074034214019775
# counter : 101
# predicted_words : [' how', ' he', ' the', ' my', ' your']
# 50
# total_tokens : 8196
# time : 40.471128940582275
# counter : 102
# predicted_words : [' r', ' my', ' the', ' a', ' j']
# 50
# total_tokens : 8276
# time : 40.86829495429993
# counter : 103
# predicted_words : [' attic', ' room', ' house', ' bedroom', ' closet']
# 51
# total_tokens : 8364
# time : 41.26647162437439
# counter : 104
# predicted_words : [' youth', ' young', ' boy', ' kid', ' man']
# 52
# total_tokens : 8463
# time : 41.68090558052063
# counter : 105
# predicted_words : [' the', ' gre', ' them', ' one', ' g']
# 52
# total_tokens : 8530
# time : 42.07795715332031
# counter : 106
# predicted_words : [' some', ' new', ' a', ' any', ' my']
# 52
# total_tokens : 8602
# time : 42.474833726882935
# counter : 107
# predicted_words : [' rumors', ' engagement', ' marriage', ' possible', ' rumor']
# 53
# total_tokens : 8686
# time : 42.87272381782532
# counter : 108
# predicted_words : [' ot', ' the', ' mr', ' ott', ' o']
# 53
# total_tokens : 8768
# time : 43.2701473236084
# counter : 109
# predicted_words : [' the', ' a', ' an', ' his', ' what']
# 53
# total_tokens : 8849
# time : 43.66802668571472
# counter : 110
# predicted_words : [' get', ' fall', ' be', ' crash', ' have']
# 53
# total_tokens : 8913
# time : 44.04147243499756
# counter : 111
# predicted_words : [' fel', ' k', ' e', ' the', ' a']
# 53
# total_tokens : 8996
# time : 44.43876075744629
# counter : 112
# predicted_words : [' a', ' yes', ' an', ' been', ',']
# 54
# total_tokens : 9078
# time : 44.83581829071045
# counter : 113
# predicted_words : [' cas', ' the', ' captain', ' Cas', ' p']
# 54
# total_tokens : 9153
# time : 45.23319864273071
# counter : 114
# predicted_words : [' lay', ' him', ' the', ' my', ' them']
# 54
# total_tokens : 9230
# time : 45.63041424751282
# counter : 115
# predicted_words : [' legion', ' the', ' her', ' a', ' his']
# 55
# total_tokens : 9313
# time : 46.02841258049011
# counter : 116
# predicted_words : ['.', ',', ' keys', ' for', ' too']
# 56
# total_tokens : 9388
# time : 46.42537760734558
# counter : 117
# predicted_words : [' rocky', ' rock', ' the', ' am', ' ruby']
# 57
# total_tokens : 9450
# time : 46.7988760471344
# counter : 118
# predicted_words : [' one', ' more', ' trust', ' place', ' such']
# 58
# total_tokens : 9520
# time : 47.19673156738281
# counter : 119
# predicted_words : [" ''", ' "', ' todd', ' ``', ' t']
# 59
# total_tokens : 9592
# time : 47.59439492225647
# counter : 120
# predicted_words : [" ''", ' eth', ' i', ' and', ' j']
# 59
# total_tokens : 9707
# time : 48.009655237197876
# counter : 121
# predicted_words : [' cot', ' bed', ' mattress', ' metal', ' wooden']
# 60
# total_tokens : 9778
# time : 48.406010389328
# counter : 122
# predicted_words : [' wives', ' giving', ' women', ' the', ' people']
# 61
# total_tokens : 9849
# time : 48.802881479263306
# counter : 123
# predicted_words : [' though', ' but', ' m', ' so', ' now']
# 61
# total_tokens : 9926
# time : 49.19980216026306
# counter : 124
# predicted_words : [' it', ' j', ' him', ' the', ' his']
# 61
# total_tokens : 10015
# time : 49.59833765029907
# counter : 125
# predicted_words : [' patt', ' the', ' p', ' pat', ' co']
# 61
# total_tokens : 10090
# time : 49.995453119277954
# counter : 126
# predicted_words : [' him', ' ot', ' your', ' that', ' the']
# 61
# total_tokens : 10165
# time : 50.39295172691345
# counter : 127
# predicted_words : [' vern', ' al', ' my', ' a', ' the']
# 61
# total_tokens : 10237
# time : 50.789740562438965
# counter : 128
# predicted_words : [' sim', ' the', ' her', ' getting', ' what']
# 61
# total_tokens : 10340
# time : 51.20436644554138
# counter : 129
# predicted_words : [' deep', '.', ',', ' -', ' and']
# 62
# total_tokens : 10470
# time : 51.65811371803284
# counter : 130
# predicted_words : [' her', ' a', ' one', ' like', ' hers']
# 63
# total_tokens : 10553
# time : 52.055861473083496
# counter : 131
# predicted_words : [' ge', ' mamm', ' him', ' them', ' mam']
# 63
# total_tokens : 10640
# time : 52.454103231430054
# counter : 132
# predicted_words : [' jo', ' but', ' i', ' and', " ''"]
# 63
# total_tokens : 10718
# time : 52.85121178627014
# counter : 133
# predicted_words : [' princess', ' king', ' queen', ' young', ' girl']
# 64
# total_tokens : 10821
# time : 53.2662456035614
# counter : 134
# predicted_words : [' towel', ' arm', ' hand', ' shirt', ' shoulder']
# 65
# total_tokens : 10891
# time : 53.66354513168335
# counter : 135
# predicted_words : [' qu', ' miss', ' land', ' j', ' l']
# 65
# total_tokens : 10963
# time : 54.060229778289795
# counter : 136
# predicted_words : [' a', ' too', ' pretty', ' nice', ' just']
# 66
# total_tokens : 11066
# time : 54.47490334510803
# counter : 137
# predicted_words : [' doc', ' then', " ''", ' i', ' ``']
# 66
# total_tokens : 11143
# time : 54.873117446899414
# counter : 138
# predicted_words : [' stake', ' wooden', ' missing', ' metal', ' wood']
# 67
# total_tokens : 11235
# time : 55.272093057632446
# counter : 139
# predicted_words : [' them', ' us', ' the', ' bel', ' me']
# 67
# total_tokens : 11342
# time : 55.6870322227478
# counter : 140
# predicted_words : [' ella', ' elle', ' i', ' ell', ' el']
# 68
# total_tokens : 11416
# time : 56.08461666107178
# counter : 141
# predicted_words : [' toll', ' his', ' tol', ' the', ' to']
# 68
# total_tokens : 11502
# time : 56.482505798339844
# counter : 142
# predicted_words : [' kell', ' the', ' his', ' look', ' him']
# 68
# total_tokens : 11584
# time : 56.880051136016846
# counter : 143
# predicted_words : [' pop', ' the', ' her', ' a', ' Pop']
# 68
# total_tokens : 11661
# time : 57.27719688415527
# counter : 144
# predicted_words : [' gar', ' sp', ' g', ' john', ' the']
# 68
# total_tokens : 11734
# time : 57.67499375343323
# counter : 145
# predicted_words : [' de', ' in', ' suffering', ' quite', ' ill']
# 68
# total_tokens : 11806
# time : 58.07312250137329
# counter : 146
# predicted_words : [' ric', ' but', ' i', ' my', ' it']
# 68
# total_tokens : 11883
# time : 58.47054171562195
# counter : 147
# predicted_words : [' organization', ' alliance', ' group', ' place', ' company']
# 69
# total_tokens : 11968
# time : 58.86877179145813
# counter : 148
# predicted_words : [' deserted', ' a', '.', ' an', ',']
# 70
# total_tokens : 12031
# time : 59.24211096763611
# counter : 149
# predicted_words : [' ab', ' help', ' the', ' his', ' marshal']
# 70
# total_tokens : 12137
# time : 59.65733003616333
# counter : 150
# predicted_words : [' know', ' see', ' ken', 'see', ' ve']
# 70
# total_tokens : 12211
# time : 60.05477285385132
# counter : 151
# predicted_words : [' h', ' the', ' hans', ' pr', ' his']
# 70
# total_tokens : 12285
# time : 60.452152729034424
# counter : 152
# predicted_words : ['.', ',', '...', ' today', ' now']
# 70
# total_tokens : 12363
# time : 60.84959053993225
# counter : 153
# predicted_words : [' bear', ' cub', ' mother', ' other', ' wolf']
# 71
# total_tokens : 12454
# time : 61.24811863899231
# counter : 154
# predicted_words : [' love', ' the', ' all', ' enough', ' it']
# 72
# total_tokens : 12533
# time : 61.645875453948975
# counter : 155
# predicted_words : [' --', ' coast', ' skip', " ''", ' variation']
# 72
# total_tokens : 12663
# time : 62.09997057914734
# counter : 156
# predicted_words : [' witches', ' psych', ' li', ' winners', ' vampires']
# 73
# total_tokens : 12734
# time : 62.49724340438843
# counter : 157
# predicted_words : [' dam', ' valley', ' pond', ' pool', ' wall']
# 74
# total_tokens : 12822
# time : 62.89532136917114
# counter : 158
# predicted_words : [' pat', ' him', ' the', ' her', ' his']
# 74
# total_tokens : 12894
# time : 63.29308271408081
# counter : 159
# predicted_words : [' rope', ' wall', ' ladder', ' ropes', ' hand']
# 75
# total_tokens : 12973
# time : 63.69084358215332
# counter : 160
# predicted_words : [' prey', ' lion', ' one', ' only', ' victim']
# 76
# total_tokens : 13042
# time : 64.08718800544739
# counter : 161
# predicted_words : [' not', ' sure', ' a', ' hungry', ' just']
# 77
# total_tokens : 13121
# time : 64.48451209068298
# counter : 162
# predicted_words : [' j', ' tom', ' a', ' the', ' el']
# 77
# total_tokens : 13191
# time : 64.88161087036133
# counter : 163
# predicted_words : [' vict', ' uncle', ' the', ' her', ' char']
# 77
# total_tokens : 13294
# time : 65.29659676551819
# counter : 164
# predicted_words : [' the', ' pier', ' his', ' p', ' me']
# 77
# total_tokens : 13362
# time : 65.69407415390015
# counter : 165
# predicted_words : [' able', ' playing', ' a', ' involved', ' messing']
# 78
# total_tokens : 13446
# time : 66.09177684783936
# counter : 166
# predicted_words : [' gag', ' ropes', ' rope', ' duct', ' tape']
# 79
# total_tokens : 13532
# time : 66.4887342453003
# counter : 167
# predicted_words : [' her', ' a', ' the', ' them', ' ath']
# 79
# total_tokens : 13628
# time : 66.88746762275696
# counter : 168
# predicted_words : [' rak', ' the', ' a', ' r', ' my']
# 79
# total_tokens : 13707
# time : 67.28530406951904
# counter : 169
# predicted_words : [' co', ' the', ' a', ' one', ' an']
# 79
# total_tokens : 13773
# time : 67.68294215202332
# counter : 170
# predicted_words : [' head', ' tooth', ' face', ' pink', ' brush']
# 79
# total_tokens : 13848
# time : 68.08057713508606
# counter : 171
# predicted_words : [' drugs', ' drug', ' work', ' plants', ' job']
# 80
# total_tokens : 13916
# time : 68.47705554962158
# counter : 172
# predicted_words : [' t', ' j', ' the', ' she', '.']
# 80
# total_tokens : 13987
# time : 68.87242197990417
# counter : 173
# predicted_words : [' j', ' d', ' sh', ' and', " ''"]
# 80
# total_tokens : 14064
# time : 69.27000212669373
# counter : 174
# predicted_words : [' ax', ' him', ' the', ' n', ' Axel']
# 80
# total_tokens : 14149
# time : 69.66850709915161
# counter : 175
# predicted_words : [' desert', ' rock', ' area', ' middle', ' ground']
# 81
# total_tokens : 14252
# time : 70.08329772949219
# counter : 176
# predicted_words : [' let', ' o', ' the', ' john', ' sus']
# 81
# total_tokens : 14337
# time : 70.48120880126953
# counter : 177
# predicted_words : [' ball', ' beautiful', ' princess', ' little', ' dancer']
# 81
# total_tokens : 14417
# time : 70.87846493721008
# counter : 178
# predicted_words : [' priest', ' parish', ' man', ' father', ',']
# 82
# total_tokens : 14502
# time : 71.2766649723053
# counter : 179
# predicted_words : [' mat', '.', ' the', ',', ' her']
# 82
# total_tokens : 14585
# time : 71.673983335495
# counter : 180
# predicted_words : [' home', ' place', " ''", ' house', ' good']
# 83
# total_tokens : 14656
# time : 72.07126784324646
# counter : 181
# predicted_words : [' a', ' the', ' her', ' take', ' alex']
# 83
# total_tokens : 14733
# time : 72.46874403953552
# counter : 182
# predicted_words : [' k', ' the', ' ken', ' james', ' kenn']
# 83
# total_tokens : 14822
# time : 72.8664026260376
# counter : 183
# predicted_words : [' but', ' notice', ' noticing', ' responding', ' respond']
# 83
# total_tokens : 14896
# time : 73.26366829872131
# counter : 184
# predicted_words : [' par', ' paralyzed', ' so', ' in', ' n']
# 83
# total_tokens : 14970
# time : 73.66069912910461
# counter : 185
# predicted_words : [' trouble', ' easy', ' fight', ' good', ' fights']
# 84
# total_tokens : 15061
# time : 74.05846071243286
# counter : 186
# predicted_words : [' roy', ' her', ' c', ' the', ' ro']
# 84
# total_tokens : 15144
# time : 74.45652675628662
# counter : 187
# predicted_words : [' nightmare', ' dream', ' bad', ' flashback', ' vision']
# 85
# total_tokens : 15220
# time : 74.85446095466614
# counter : 188
# predicted_words : [' were', ' you', ' but', ' my', " ''"]
# 85
# total_tokens : 15314
# time : 75.25302457809448
# counter : 189
# predicted_words : [' her', ' v', ' the', ' what', ' van']
# 85
# total_tokens : 15394
# time : 75.64940476417542
# counter : 190
# predicted_words : [' bl', ' j', ' dr', ' the', ' my']
# 85
# total_tokens : 15468
# time : 76.0458447933197
# counter : 191
# predicted_words : [' either', ' neither', ' too', ' but', " ''"]
# 86
# total_tokens : 15551
# time : 76.44459223747253
# counter : 192
# predicted_words : [',', '.', ' yet', ' though', ' but']
# 87
# total_tokens : 15629
# time : 76.84234309196472
# counter : 193
# predicted_words : [' moon', ' sun', ' top', ' other', ' stars']
# 88
# total_tokens : 15705
# time : 77.24002385139465
# counter : 194
# predicted_words : [' paul', ' one', ' the', ' a', ' another']
# 89
# total_tokens : 15807
# time : 77.65479922294617
# counter : 195
# predicted_words : [' her', ' slo', ' his', ' the', ' anyone']
# 89
# total_tokens : 15888
# time : 78.05174684524536
# counter : 196
# predicted_words : [' all', ' the', ' his', ' her', ' me']
# 89
# total_tokens : 15973
# time : 78.44951629638672
# counter : 197
# predicted_words : [' m', ' k', ' j', ' l', ' em']
# 89
# total_tokens : 16043
# time : 78.84667038917542
# counter : 198
# predicted_words : [' box', ' backpack', ' diary', ' pack', ' black']
# 90
# total_tokens : 16134
# time : 79.24509167671204
# counter : 199
# predicted_words : [' running', ' in', ' on', ' the', ' distance']
# 91
# total_tokens : 16203
# time : 79.64203548431396
# counter : 200
# predicted_words : [' oz', ' the', ' j', ' k', ' l']
# 92
# total_tokens : 16274
# time : 80.03906416893005
# counter : 201
# predicted_words : [' sweater', ' gift', ' present', ' christmas', ' Christmas']
# 93
# total_tokens : 16339
# time : 80.43548488616943
# counter : 202
# predicted_words : [' er', ' try', ' j', ' k', ' t']
# 93
# total_tokens : 16414
# time : 80.8329770565033
# counter : 203
# predicted_words : [" ''", ' you', ' star', ' i', ' ``']
# 93
# total_tokens : 16487
# time : 81.2299370765686
# counter : 204
# predicted_words : [' new', ' modern', ' big', ' block', ' bunch']
# 93
# total_tokens : 16562
# time : 81.6279296875
# counter : 205
# predicted_words : [' keypad', ' keyboard', ' keys', ' screen', ' board']
# 94
# total_tokens : 16635
# time : 82.02530193328857
# counter : 206
# predicted_words : [' ambulance', ' car', ' tent', ' house', ' front']
# 95
# total_tokens : 16713
# time : 82.42256665229797
# counter : 207
# predicted_words : [' rusty', ' the', ' her', ' rust', ' him']
# 96
# total_tokens : 16810
# time : 82.83711433410645
# counter : 208
# predicted_words : [' luc', ' her', ' the', ' l', ' j']
# 96
# total_tokens : 16886
# time : 83.23392057418823
# counter : 209
# predicted_words : [' her', ' the', ' me', ' ben', ' him']
# 96
# total_tokens : 16955
# time : 83.63115668296814
# counter : 210
# predicted_words : [' drink', ' tantr', ' rest', ' drinking', ' fact']
# 97
# total_tokens : 17033
# time : 84.0288758277893
# counter : 211
# predicted_words : [' panel', ' wooden', ' wood', ' board', ' heavy']
# 98
# total_tokens : 17107
# time : 84.42648124694824
# counter : 212
# predicted_words : [' maps', '.', ' for', ',', ' and']
# 99
# total_tokens : 17208
# time : 84.84100294113159
# counter : 213
# predicted_words : [' man', ' guy', ' thing', ' one', ' dance']
# 99
# total_tokens : 17281
# time : 85.23816633224487
# counter : 214
# predicted_words : [' mass', ' service', ' chance', ' prayer', ' priest']
# 100
# total_tokens : 17368
# time : 85.63628840446472
# counter : 215
# predicted_words : [' two', ' four', ' all', ' both', ' three']
# 101
# total_tokens : 17450
# time : 86.03385066986084
# counter : 216
# predicted_words : [' matt', ' the', ' mat', ' him', ' m']
# 102
# total_tokens : 17583
# time : 86.48791456222534
# counter : 217
# predicted_words : [" ''", ' "', ' your', ' eh', ' is']
# 102
# total_tokens : 17661
# time : 86.8856508731842
# counter : 218
# predicted_words : [' than', ' wizards', ' of', ' powerful', ' to']
# 103
# total_tokens : 17735
# time : 87.28337383270264
# counter : 219
# predicted_words : [' good', ' real', ' friend', ' reputable', ' client']
# 104
# total_tokens : 17805
# time : 87.68050909042358
# counter : 220
# predicted_words : [' ok', ' the', ' this', ' japan', ' my']
# 104
# total_tokens : 17881
# time : 88.07723188400269
# counter : 221
# predicted_words : [' a', ' giants', ' giant', ' ghosts', ' the']
# 105
# total_tokens : 17948
# time : 88.47489619255066
# counter : 222
# predicted_words : [' tr', ' the', ' fre', ' his', ' a']
# 105
# total_tokens : 18040
# time : 88.87350296974182
# counter : 223
# predicted_words : [' follower', ' followers', ' following', ' man', ' time']
# 106
# total_tokens : 18114
# time : 89.27048945426941
# counter : 224
# predicted_words : [' the', ' my', ' graduation', ' school', ' class']
# 107
# total_tokens : 18202
# time : 89.66826367378235
# counter : 225
# predicted_words : [' single', ' a', ' so', ' unmarried', ' not']
# 108
# total_tokens : 18281
# time : 90.06494188308716
# counter : 226
# predicted_words : [' bro', ' handle', ' end', ' stick', ' long']
# 108
# total_tokens : 18362
# time : 90.46362233161926
# counter : 227
# predicted_words : [' mug', ' te', ' cup', ' plate', ' t']
# 109
# total_tokens : 18449
# time : 90.86238431930542
# counter : 228
# predicted_words : [' body', ' dead', ' corpse', ' scene', ' man']
# 110
# total_tokens : 18547
# time : 91.27719902992249
# counter : 229
# predicted_words : [' mine', ' ours', ' theirs', ' my', ' yours']
# 111
# total_tokens : 18608
# time : 91.65055346488953
# counter : 230
# predicted_words : [' s', 'out', ' his', ' her', ' the']
# 111
# total_tokens : 18677
# time : 92.04741621017456
# counter : 231
# predicted_words : [' recover', ' get', ' make', ' be', '?']
# 112
# total_tokens : 18754
# time : 92.44487071037292
# counter : 232
# predicted_words : ['.', ' lost', ' stuff', ' shit', ' stock']
# 112
# total_tokens : 18823
# time : 92.8418083190918
# counter : 233
# predicted_words : [' a', ' reinc', ' the', ' an', ',']
# 112
# total_tokens : 18898
# time : 93.2393159866333
# counter : 234
# predicted_words : [' ram', ' sp', ' the', ' a', ' he']
# 112
# total_tokens : 18990
# time : 93.63721299171448
# counter : 235
# predicted_words : [' log', ' him', ' the', ' a', ' this']
# 112
# total_tokens : 19085
# time : 94.03598523139954
# counter : 236
# predicted_words : [' sim', ' him', ' someone', ' her', ' the']
# 112
# total_tokens : 19176
# time : 94.43391728401184
# counter : 237
# predicted_words : [' wig', ' the', ' w', ' Wig', ' bag']
# 112
# total_tokens : 19266
# time : 94.83219361305237
# counter : 238
# predicted_words : [' night', ' gown', ' garment', ' white', ' l']
# 112
# total_tokens : 19356
# time : 95.23011898994446
# counter : 239
# predicted_words : [' ann', ' she', ' he', ' the', ' anyone']
# 112
# total_tokens : 19423
# time : 95.62625861167908
# counter : 240
# predicted_words : [' death', ' life', ' closest', ' only', ' love']
# 112
# total_tokens : 19494
# time : 96.02317094802856
# counter : 241
# predicted_words : [' motives', ' motive', ' motivations', ' motivation', ' intentions']
# 113
# total_tokens : 19574
# time : 96.4210524559021
# counter : 242
# predicted_words : [' cardinal', ' bishop', ' arch', ' pope', ' ab']
# 114
# total_tokens : 19650
# time : 96.81768274307251
# counter : 243
# predicted_words : [' asked', ' told', ' called', ' caught', ' in']
# 115
# total_tokens : 19737
# time : 97.21556687355042
# counter : 244
# predicted_words : [' pet', ' the', ' him', ' her', ' ch']
# 115
# total_tokens : 19811
# time : 97.61237740516663
# counter : 245
# predicted_words : [' be', ' my', ' me', ' the', ' l']
# 115
# total_tokens : 19906
# time : 98.01060557365417
# counter : 246
# predicted_words : [' eat', ' go', ' work', ' cook', ' wait']
# 115
# total_tokens : 19977
# time : 98.40799474716187
# counter : 247
# predicted_words : [' is', ' if', ' does', ' did', ' was']
# 115
# total_tokens : 20063
# time : 98.80665993690491
# counter : 248
# predicted_words : ['.', ',', ' and', '...', ' "']
# 115
# total_tokens : 20145
# time : 99.20420932769775
# counter : 249
# predicted_words : [' step', ' i', ' that', ' sir', ' but']
# 115
# total_tokens : 20224
# time : 99.60168170928955
# counter : 250
# predicted_words : [' shovel', ' sh', ' snow', ' hand', ' second']
# 116
# total_tokens : 20300
# time : 99.99783730506897
# counter : 251
# predicted_words : [' tur', ' the', ' gar', ' t', ' j']
# 116
# total_tokens : 20372
# time : 100.39547228813171
# counter : 252
# predicted_words : [' e', ' he', ' the', ' that', ' E']
# 116
# total_tokens : 20461
# time : 100.79351615905762
# counter : 253
# predicted_words : [' fort', ' lee', ' as', ' the', ' a']
# 117
# total_tokens : 20538
# time : 101.1910228729248
# counter : 254
# predicted_words : [' luc', ' l', ' the', ' she', ' Lucy']
# 117
# total_tokens : 20618
# time : 101.58817338943481
# counter : 255
# predicted_words : [' speed', ' pace', ' white', ' es', ' lot']
# 117
# total_tokens : 20760
# time : 102.0430052280426
# counter : 256
# predicted_words : [' tray', ' table', ' strange', ' box', ' bed']
# 118
# total_tokens : 20843
# time : 102.4409692287445
# counter : 257
# predicted_words : ['.', ' and', ',', ' that', ' of']
# 118
# total_tokens : 20919
# time : 102.83875751495361
# counter : 258
# predicted_words : [' miss', ' em', ' Ms', ' Miss', ' Mrs']
# 118
# total_tokens : 20993
# time : 103.23660206794739
# counter : 259
# predicted_words : [' b', ' buddy', ' ben', ' boss', ' and']
# 118
# total_tokens : 21073
# time : 103.63358569145203
# counter : 260
# predicted_words : [' light', ' soul', ' hope', ' way', ' life']
# 119
# total_tokens : 21151
# time : 104.03136324882507
# counter : 261
# predicted_words : [" ''", ' st', ' but', ' my', ' ``']
# 119
# total_tokens : 21233
# time : 104.4285535812378
# counter : 262
# predicted_words : [' suspicion', ' mistr', ' distrust', ' fear', ' paranoia']
# 120
# total_tokens : 21315
# time : 104.82566809654236
# counter : 263
# predicted_words : [' spell', ' thing', ' powerful', ' ritual', ' charm']
# 121
# total_tokens : 21394
# time : 105.22349691390991
# counter : 264
# predicted_words : [' effect', ' place', ' full', ' the', ' play']
# 121
# total_tokens : 21486
# time : 105.62153315544128
# counter : 265
# predicted_words : [' her', ' the', ' me', ' fel', ' del']
# 121
# total_tokens : 21567
# time : 106.01848006248474
# counter : 266
# predicted_words : [' tw', ' the', ' r', ' two', ' a']
# 121
# total_tokens : 21647
# time : 106.41593980789185
# counter : 267
# predicted_words : [' her', ' grace', ' the', ' not', ',']
# 122
# total_tokens : 21734
# time : 106.8132095336914
# counter : 268
# predicted_words : [' sheriff', ' sher', ' sh', ' police', '...']
# 123
# total_tokens : 21803
# time : 107.20912027359009
# counter : 269
# predicted_words : [' r', ' him', ' this', ' alex', ' you']
# 123
# total_tokens : 21875
# time : 107.60527753829956
# counter : 270
# predicted_words : [" ''", ' but', ' actually', " '", ' log']
# 123
# total_tokens : 21944
# time : 108.00172185897827
# counter : 271
# predicted_words : [' music', ' dancing', ' to', ' dance', ' the']
# 124
# total_tokens : 22015
# time : 108.39948272705078
# counter : 272
# predicted_words : [' taken', ' responded', ' been', ' laughed', ' reacted']
# 125
# total_tokens : 22108
# time : 108.7980043888092
# counter : 273
# predicted_words : [' stick', ' branch', ' drawing', ' pen', ' tree']
# 126
# total_tokens : 22216
# time : 109.21301889419556
# counter : 274
# predicted_words : [' wal', ' j', ' w', ' wil', ' walnut']
# 126
# total_tokens : 22293
# time : 109.61016178131104
# counter : 275
# predicted_words : [' supposed', ' translated', ' said', ' going', ' spelled']
# 127
# total_tokens : 22371
# time : 110.00802946090698
# counter : 276
# predicted_words : [' the', ' her', ' d', ' his', ' j']
# 127
# total_tokens : 22458
# time : 110.40674877166748
# counter : 277
# predicted_words : [',', ' it', " '", ' -', '...']
# 127
# total_tokens : 22527
# time : 110.80321383476257
# counter : 278
# predicted_words : [' nap', ' missing', ' lost', ' table', ' paper']
# 127
# total_tokens : 22609
# time : 111.20063376426697
# counter : 279
# predicted_words : [' bon', ' he', ' the', ' a', ' j']
# 127
# total_tokens : 22688
# time : 111.5982575416565
# counter : 280
# predicted_words : [' hand', ' pleasure', ' last', ' fist', ' turn']
# 128
# total_tokens : 22763
# time : 111.995534658432
# counter : 281
# predicted_words : [' har', ' i', ' she', ' the', ' my']
# 128
# total_tokens : 22831
# time : 112.39282870292664
# counter : 282
# predicted_words : [' boss', ' gold', ' dragon', ' monster', ' beast']
# 129
# total_tokens : 22894
# time : 112.76616525650024
# counter : 283
# predicted_words : [' el', ' the', ' e', ' lady', ' mad']
# 129
# total_tokens : 22970
# time : 113.1644184589386
# counter : 284
# predicted_words : [' electron', ' particle', ' wave', ' ball', ' electrons']
# 130
# total_tokens : 23042
# time : 113.56208086013794
# counter : 285
# predicted_words : [' c', ' the', ' em', ' king', ' k']
# 130
# total_tokens : 23135
# time : 113.96083164215088
# counter : 286
# predicted_words : [' him', ' set', ' them', ' the', ' that']
# 130
# total_tokens : 23217
# time : 114.35774254798889
# counter : 287
# predicted_words : [' damp', ' wet', ' a', ' warm', ' dripping']
# 131
# total_tokens : 23294
# time : 114.75420713424683
# counter : 288
# predicted_words : [' fountain', ' water', ' f', ' park', ' same']
# 132
# total_tokens : 23363
# time : 115.15097665786743
# counter : 289
# predicted_words : [' cand', ' j', ' k', ' c', ' the']
# 132
# total_tokens : 23441
# time : 115.54926323890686
# counter : 290
# predicted_words : [' the', ' his', ' a', ' d', ' everyone']
# 132
# total_tokens : 23510
# time : 115.94603300094604
# counter : 291
# predicted_words : [' shared', ' mutual', " '", ' secret', ' gossip']
# 132
# total_tokens : 23595
# time : 116.34336590766907
# counter : 292
# predicted_words : [' faction', ' group', ' place', ' Faction', ' room']
# 133
# total_tokens : 23670
# time : 116.74093627929688
# counter : 293
# predicted_words : [' d', ' paul', ' the', ' my', ' him']
# 133
# total_tokens : 23760
# time : 117.13883376121521
# counter : 294
# predicted_words : [' recycle', ' sit', ' throw', ' toss', ' dump']
# 134
# total_tokens : 23836
# time : 117.53557515144348
# counter : 295
# predicted_words : [' do', ' right', ' e', " ''", ' i']
# 134
# total_tokens : 23908
# time : 117.93341422080994
# counter : 296
# predicted_words : [' univers', ' people', ' stuff', ' work', ' information']
# 134
# total_tokens : 24003
# time : 118.33169460296631
# counter : 297
# predicted_words : [' four', ' men', ' group', ' people', ' table']
# 135
# total_tokens : 24078
# time : 118.7286159992218
# counter : 298
# predicted_words : [' me', ' i', ' the', ' school', ' just']
# 136
# total_tokens : 24156
# time : 119.12703919410706
# counter : 299
# predicted_words : [' my', ' mine', ' the', ' marrying', ' m']
# 137
# total_tokens : 24223
# time : 119.52413702011108
# counter : 300
# predicted_words : [' w', ' the', ' i', ' j', ' my']
# 137
# total_tokens : 24311
# time : 119.92213869094849
# counter : 301
# predicted_words : [' cheating', ' a', ' gay', ' against', ' illegal']
# 138
# total_tokens : 24379
# time : 120.31971001625061
# counter : 302
# predicted_words : [' temper', ' bad', ' short', ' anger', ' big']
# 139
# total_tokens : 24449
# time : 120.71708559989929
# counter : 303
# predicted_words : [' soph', ' his', ' him', ' the', ' a']
# 139
# total_tokens : 24530
# time : 121.11546325683594
# counter : 304
# predicted_words : [' me', ' the', ' bra', ' her', ' him']
# 139
# total_tokens : 24603
# time : 121.51241755485535
# counter : 305
# predicted_words : [' cash', ' credit', ' a', ' in', ' ten']
# 140
# total_tokens : 24681
# time : 121.90948700904846
# counter : 306
# predicted_words : [' pack', ' brothers', ' wolves', ' kind', ' people']
# 141
# total_tokens : 24790
# time : 122.32457208633423
# counter : 307
# predicted_words : [' witch', ' gnome', ' baby', ' wizard', ' g']
# 142
# total_tokens : 24871
# time : 122.72218799591064
# counter : 308
# predicted_words : [' brush', ' br', ' paint', ' small', ' door']
# 143
# total_tokens : 24939
# time : 123.11886930465698
# counter : 309
# predicted_words : [' bee', " ''", ' Bee', ' then', ' be']
# 144
# total_tokens : 25008
# time : 123.51669263839722
# counter : 310
# predicted_words : [' face', ' the', ' ha', ' look', ' her']
# 144
# total_tokens : 25080
# time : 123.91477489471436
# counter : 311
# predicted_words : [' r', ' don', " ''", ' right', ' buddy']
# 144
# total_tokens : 25149
# time : 124.31249904632568
# counter : 312
# predicted_words : [' problem', ' hesitation', ' trouble', ' problems', ' question']
# 145
# total_tokens : 25245
# time : 124.71203541755676
# counter : 313
# predicted_words : [' c', " ''", ' miss', ' Catherine', ' cat']
# 145
# total_tokens : 25332
# time : 125.11020064353943
# counter : 314
# predicted_words : [" ''", ' marsh', ' jul', ' i', ' amy']
# 145
# total_tokens : 25412
# time : 125.50802183151245
# counter : 315
# predicted_words : [' imagining', ' not', ' going', ' doing', ' noticing']
# 146
# total_tokens : 25498
# time : 125.9062569141388
# counter : 316
# predicted_words : [' a', ' dignity', ' more', ' the', ' to']
# 147
# total_tokens : 25588
# time : 126.3051872253418
# counter : 317
# predicted_words : [' reputation', ' girlfriend', ' heart', ' very', ' wife']
# 147
# total_tokens : 25658
# time : 126.70173144340515
# counter : 318
# predicted_words : [' gar', ' the', ' his', ' g', ' her']
# 147
# total_tokens : 25748
# time : 127.09948778152466
# counter : 319
# predicted_words : [' thief', ' one', ' person', ' man', ' god']
# 148
# total_tokens : 25820
# time : 127.49712800979614
# counter : 320
# predicted_words : [' k', ' my', ' kro', ' kr', ' ro']
# 148
# total_tokens : 25916
# time : 127.89518594741821
# counter : 321
# predicted_words : [' h', '?', " ''", '\xa0', '...']
# 148
# total_tokens : 25999
# time : 128.29293990135193
# counter : 322
# predicted_words : [' set', ' j', ' the', ' s', ' a']
# 148
# total_tokens : 26069
# time : 128.6902322769165
# counter : 323
# predicted_words : [' her', ' j', ' the', ' his', ' him']
# 148
# total_tokens : 26159
# time : 129.08925938606262
# counter : 324
# predicted_words : [' smile', ' bow', ' wave', ' handshake', ' hello']
# 149
# total_tokens : 26224
# time : 129.4877414703369
# counter : 325
# predicted_words : [' way', '.', ' street', ' road', ',']
# 150
# total_tokens : 26348
# time : 129.90510869026184
# counter : 326
# predicted_words : [' char', ' her', ' the', ' his', ' Charlie']
# 150
# total_tokens : 26424
# time : 130.30261206626892
# counter : 327
# predicted_words : [' police', ' cops', ' watch', ' cop', ' sheriff']
# 151
# total_tokens : 26504
# time : 130.70171213150024
# counter : 328
# predicted_words : [' luc', ' ed', ' e', ' the', ' j']
# 151
# total_tokens : 26585
# time : 131.09897994995117
# counter : 329
# predicted_words : [' do', ' join', ' be', ' come', ' want']
# 152
# total_tokens : 26654
# time : 131.49579191207886
# counter : 330
# predicted_words : [' maze', ' one', '.', ' section', ' room']
# 153
# total_tokens : 26735
# time : 131.89269375801086
# counter : 331
# predicted_words : [' math', ' the', ' Math', ' a', ' adam']
# 153
# total_tokens : 26821
# time : 132.29093265533447
# counter : 332
# predicted_words : [' charming', ' the', ' malicious', ' char', ' mal']
# 154
# total_tokens : 26889
# time : 132.68846797943115
# counter : 333
# predicted_words : [' cds', ' discs', ' cd', ' two', ' music']
# 155
# total_tokens : 26972
# time : 133.0860800743103
# counter : 334
# predicted_words : [' helicopter', ' sky', ' ch', ' police', ' cop']
# 156
# total_tokens : 27041
# time : 133.4832649230957
# counter : 335
# predicted_words : [' working', ' putting', ' assembling', ' solving', ' looking']
# 157
# total_tokens : 27126
# time : 133.88185787200928
# counter : 336
# predicted_words : [' it', ' this', ' killing', ' bringing', ' using']
# 157
# total_tokens : 27205
# time : 134.2786989212036
# counter : 337
# predicted_words : [' dock', ' boat', ' water', ' shore', ' house']
# 158
# total_tokens : 27313
# time : 134.69367790222168
# counter : 338
# predicted_words : [' tub', ' bathtub', ' water', ' bath', ' edge']
# 159
# total_tokens : 27417
# time : 135.10845947265625
# counter : 339
# predicted_words : [' what', ' i', ' why', ' yeah', ' kara']
# 159
# total_tokens : 27496
# time : 135.50576162338257
# counter : 340
# predicted_words : [' candle', ' light', ' flick', ' dim', ' sudden']
# 159
# total_tokens : 27564
# time : 135.90245127677917
# counter : 341
# predicted_words : [' little', ' dragon', ' poor', ' old', ' creature']
# 160
# total_tokens : 27643
# time : 136.30012893676758
# counter : 342
# predicted_words : [" '", ' just', ' get', ' talk', ' have']
# 160
# total_tokens : 27754
# time : 136.7150354385376
# counter : 343
# predicted_words : [' park', ' food', ' campus', ' clock', ' street']
# 161
# total_tokens : 27826
# time : 137.11251211166382
# counter : 344
# predicted_words : [' vict', ' the', ' my', ' v', ' a']
# 161
# total_tokens : 27901
# time : 137.51077103614807
# counter : 345
# predicted_words : [' kn', ' grey', ' the', ' k', ' gray']
# 161
# total_tokens : 27975
# time : 137.90697717666626
# counter : 346
# predicted_words : [' recipes', ' classified', ' not', ' in', ' secret']
# 162
# total_tokens : 28072
# time : 138.3210427761078
# counter : 347
# predicted_words : [' restless', ' tired', ' weary', ' lonely', ' stir']
# 162
# total_tokens : 28151
# time : 138.7183699607849
# counter : 348
# predicted_words : [' lis', ' my', ' l', ' the', ' her']
# 162
# total_tokens : 28238
# time : 139.11641454696655
# counter : 349
# predicted_words : [' fleet', ' people', ' ships', ' ship', ' friends']
# 163
# total_tokens : 28315
# time : 139.5142617225647
# counter : 350
# predicted_words : [' car', ' me', ' the', ' Car', ' us']
# 163
# total_tokens : 28392
# time : 139.9117786884308
# counter : 351
# predicted_words : [' cl', ' okay', ' honey', ' please', ' will']
# 163
# total_tokens : 28472
# time : 140.3091104030609
# counter : 352
# predicted_words : [" ''", ' dam', ' honey', ' you', ' and']
# 163
# total_tokens : 28539
# time : 140.7060730457306
# counter : 353
# predicted_words : [' ab', ' the', ' my', ' her', ' a']
# 163
# total_tokens : 28614
# time : 141.10257840156555
# counter : 354
# predicted_words : [' b', ' the', ' a', ' he', ' my']
# 163
# total_tokens : 28682
# time : 141.49884796142578
# counter : 355
# predicted_words : [' c', ' but', " ''", ' i', ' and']
# 163
# total_tokens : 28754
# time : 141.89571237564087
# counter : 356
# predicted_words : [' cl', ' ste', ' the', ' j', ' k']
# 163
# total_tokens : 28840
# time : 142.29431414604187
# counter : 357
# predicted_words : [' medical', ' tent', ' med', ' hospital', ' next']
# 164
# total_tokens : 28923
# time : 142.6917221546173
# counter : 358
# predicted_words : [' j', ' tom', ' el', ' the', ' my']
# 164
# total_tokens : 29001
# time : 143.08937454223633
# counter : 359
# predicted_words : [' call', " ''", ' cra', ' dar', ' miss']
# 164
# total_tokens : 29095
# time : 143.48794102668762
# counter : 360
# predicted_words : [' may', ' the', ' look', ' his', ' face']
# 164
# total_tokens : 29167
# time : 143.8859040737152
# counter : 361
# predicted_words : [' fate', ' death', ' the', ' a', ' destiny']
# 165
# total_tokens : 29261
# time : 144.28401947021484
# counter : 362
# predicted_words : [' the', ' texas', ' town', ' your', ' this']
# 166
# total_tokens : 29329
# time : 144.680034160614
# counter : 363
# predicted_words : [' sweet', ' n', ' good', ' a', ' just']
# 167
# total_tokens : 29405
# time : 145.07824397087097
# counter : 364
# predicted_words : [' j', ' the', ' i', ' c', ' rid']
# 167
# total_tokens : 29488
# time : 145.47524428367615
# counter : 365
# predicted_words : [' mel', ' the', ' her', ' his', ' what']
# 167
# total_tokens : 29567
# time : 145.872252702713
# counter : 366
# predicted_words : [' girl', ' guy', ' waitress', ' bar', ' teacher']
# 168
# total_tokens : 29632
# time : 146.26950216293335
# counter : 367
# predicted_words : [' mercenaries', ' men', ' merc', ' three', ' group']
# 169
# total_tokens : 29708
# time : 146.6663818359375
# counter : 368
# predicted_words : ['.', ',', '!', ' all', ' ``']
# 169
# total_tokens : 29784
# time : 147.0630805492401
# counter : 369
# predicted_words : [' n', ' a', ' also', ' more', ' all']
# 169
# total_tokens : 29886
# time : 147.47767639160156
# counter : 370
# predicted_words : [' dream', ' know', ' understand', ' even', ' have']
# 170
# total_tokens : 29964
# time : 147.87513947486877
# counter : 371
# ...
# predicted_words : [' cl', ' the', ' a', ' she', ' an']
# 2438
# total_tokens : 383677
# time : 1894.788857460022
# counter : 4751
# predicted_words : [' robert', ' the', ' bob', ' ro', '.']
# 2439
# total_tokens : 383760
# time : 1895.1869497299194
# counter : 4752
# predicted_words : [' cela', ' celle', ' ela', ' m', ' cel']
# 2439
# total_tokens : 383852
# time : 1895.5850455760956
# counter : 4753
# predicted_words : [' ', ' see', ' find', ' the', ' where']
# 2439
# total_tokens : 383927
# time : 1895.982815027237
# counter : 4754
# predicted_words : [' the', ' that', ' mist', ' a', ' it']
# 2439
# total_tokens : 383998
# time : 1896.3799788951874
# counter : 4755
# predicted_words : [' cards', ' a', '.', ' and', ' he']
# 2440
# total_tokens : 384091
# time : 1896.7781193256378
# counter : 4756
# predicted_words : [' ry', ' him', ' the', ' my', ' your']
# 2440
# total_tokens : 384160
# time : 1897.1750826835632
# counter : 4757
# predicted_words : [' ez', ' gab', ' the', ' j', ' g']
# 2440
# total_tokens : 384237
# time : 1897.5721588134766
# counter : 4758
# predicted_words : [' able', ' homeless', ' a', ' disabled', '.']
# 2441
# total_tokens : 384321
# time : 1897.9702606201172
# counter : 4759
# predicted_words : [' duel', ' two', ' other', ' fight', ' battle']
# 2442
# total_tokens : 384429
# time : 1898.385118484497
# counter : 4760
# predicted_words : [' gifts', ' stuff', ' presents', ' other', ' things']
# 2443
# total_tokens : 384503
# time : 1898.7816767692566
# counter : 4761
# predicted_words : [' joint', ' cigarette', ' small', ' bag', ' blunt']
# 2444
# total_tokens : 384617
# time : 1899.1970446109772
# counter : 4762
# predicted_words : [' john', ' do', ' the', ' j', ' m']
# 2444
# total_tokens : 384685
# time : 1899.59326171875
# counter : 4763
# predicted_words : [' owner', ' man', ' waiter', ' guy', ' bar']
# 2445
# total_tokens : 384753
# time : 1899.9897603988647
# counter : 4764
# predicted_words : [' i', ' yelling', ' screaming', ' you', ' a']
# 2446
# total_tokens : 384828
# time : 1900.3875131607056
# counter : 4765
# predicted_words : [' video', ' game', ' recording', ' tape', ' movie']
# 2447
# total_tokens : 384904
# time : 1900.7846777439117
# counter : 4766
# predicted_words : [' rock', ' cave', ' rocks', ' ledge', ' c']
# 2448
# total_tokens : 385005
# time : 1901.1993176937103
# counter : 4767
# predicted_words : [' try', ' gab', ' the', ' tr', ' a']
# 2448
# total_tokens : 385078
# time : 1901.5957918167114
# counter : 4768
# predicted_words : ['.', ' as', ',', ' altogether', ' entirely']
# 2449
# total_tokens : 385174
# time : 1901.9948332309723
# counter : 4769
# predicted_words : [' video', ' monitor', ' baby', ' camera', ' crib']
# 2450
# total_tokens : 385276
# time : 1902.4095442295074
# counter : 4770
# predicted_words : [' do', " '", ' am', ' is', ' are']
# 2450
# total_tokens : 385344
# time : 1902.8065969944
# counter : 4771
# predicted_words : [' especially', ' let', ' when', ' who', ' sy']
# 2450
# total_tokens : 385422
# time : 1903.205087184906
# counter : 4772
# predicted_words : [' a', ' car', ' the', ' Aaron', ' my']
# 2450
# total_tokens : 385492
# time : 1903.602341413498
# counter : 4773
# predicted_words : [' her', ' will', ' the', ' cast', ' him']
# 2450
# total_tokens : 385566
# time : 1904.0001046657562
# counter : 4774
# predicted_words : [' glass', ' window', ' pane', ' otherwise', ' surface']
# 2451
# total_tokens : 385637
# time : 1904.3970758914948
# counter : 4775
# predicted_words : [' all', ' s', ' other', ' g', ' others']
# 2451
# total_tokens : 385710
# time : 1904.7948186397552
# counter : 4776
# predicted_words : [' a', ' no', ' the', ' permission', ' an']
# 2452
# total_tokens : 385786
# time : 1905.1926934719086
# counter : 4777
# predicted_words : [' religious', ' religion', ' church', ' for', ' churches']
# 2453
# total_tokens : 385859
# time : 1905.5902514457703
# counter : 4778
# predicted_words : [' cit', ' city', ' fortress', ' castle', ' fort']
# 2453
# total_tokens : 385948
# time : 1905.9888887405396
# counter : 4779
# predicted_words : [' ipad', ' iPad', ' electronic', ' ip', ' iphone']
# 2454
# total_tokens : 386030
# time : 1906.3864147663116
# counter : 4780
# predicted_words : [' poem', ' message', ' poetry', ' poems', ' book']
# 2455
# total_tokens : 386112
# time : 1906.7846076488495
# counter : 4781
# predicted_words : [' drive', ' stick', ' key', ' flash', ' device']
# 2456
# total_tokens : 386190
# time : 1907.182416677475
# counter : 4782
# predicted_words : [' missile', ' car', ' missiles', ' money', ' miss']
# 2457
# total_tokens : 386268
# time : 1907.5820043087006
# counter : 4783
# predicted_words : [' the', ' cat', ' them', ' him', ' his']
# 2458
# total_tokens : 386342
# time : 1907.9800992012024
# counter : 4784
# predicted_words : [' gang', ' criminal', ' mob', ' cro', ' mafia']
# 2458
# total_tokens : 386420
# time : 1908.378255367279
# counter : 4785
# predicted_words : [' christian', ' al', ' christ', ' j', ' crist']
# 2458
# total_tokens : 386484
# time : 1908.7519512176514
# counter : 4786
# predicted_words : [' music', ' photo', ' box', ' picture', ' frame']
# 2459
# total_tokens : 386551
# time : 1909.1490845680237
# counter : 4787
# predicted_words : [' s', ' him', ' me', ' dr', ' the']
# 2459
# total_tokens : 386628
# time : 1909.5467991828918
# counter : 4788
# predicted_words : [' intelligent', ' stupid', ' smart', ' bad', ' dumb']
# 2460
# total_tokens : 386705
# time : 1909.9441177845001
# counter : 4789
# predicted_words : [' the', ' her', ' cl', ' his', ' a']
# 2460
# total_tokens : 386778
# time : 1910.3416168689728
# counter : 4790
# predicted_words : [' going', ' okay', '.', ',', ' really']
# 2461
# total_tokens : 386860
# time : 1910.739827632904
# counter : 4791
# predicted_words : [' skip', ' Skip', ' sk', " ''", ' next']
# 2462
# total_tokens : 386928
# time : 1911.137217760086
# counter : 4792
# predicted_words : [' client', " '", ' potential', " ''", ' -']
# 2463
# total_tokens : 387000
# time : 1911.5342166423798
# counter : 4793
# predicted_words : [' the', ' bag', ' g', ' j', ' b']
# 2463
# total_tokens : 387081
# time : 1911.9316716194153
# counter : 4794
# predicted_words : [' step', ' miss', " ''", ' my', ' dear']
# 2463
# total_tokens : 387153
# time : 1912.3287045955658
# counter : 4795
# predicted_words : [' tank', ' tanks', ' boat', ' locker', ' air']
# 2464
# total_tokens : 387217
# time : 1912.701824426651
# counter : 4796
# predicted_words : [' sheet', ' sheets', ' hospital', ' body', ' white']
# 2465
# total_tokens : 387285
# time : 1913.0988829135895
# counter : 4797
# predicted_words : [' mid', ' hospital', ' on', ' consultant', ' doctor']
# 2465
# total_tokens : 387378
# time : 1913.4970905780792
# counter : 4798
# predicted_words : ['.', ' **', ' in', ',', ' like']
# 2465
# total_tokens : 387463
# time : 1913.8957180976868
# counter : 4799
# predicted_words : [' my', ' getting', ' even', ' a', ' going']
# 2465
# total_tokens : 387533
# time : 1914.292677640915
# counter : 4800
# predicted_words : ['.', ' and', ',', ' financially', ' if']
# 2466
# total_tokens : 387615
# time : 1914.6903364658356
# counter : 4801
# predicted_words : [' theater', ' show', ' play', ' theatre', ' concert']
# 2467
# total_tokens : 387692
# time : 1915.0884001255035
# counter : 4802
# predicted_words : [' still', ' the', ' its', ' which', ' with']
# 2467
# total_tokens : 387801
# time : 1915.5033495426178
# counter : 4803
# predicted_words : [' strawberry', ' berry', ' chocolate', ' raspberry', ' Strawberry']
# 2468
# total_tokens : 387878
# time : 1915.9014813899994
# counter : 4804
# predicted_words : [' bleeding', ' hurt', ' -', ' bad', ',']
# 2469
# total_tokens : 387976
# time : 1916.3158667087555
# counter : 4805
# predicted_words : [' code', ' codes', ' emergency', ' secret', ' combination']
# 2470
# total_tokens : 388049
# time : 1916.7128510475159
# counter : 4806
# predicted_words : [' the', ' my', ' get', ' work', ' school']
# 2470
# total_tokens : 388129
# time : 1917.1106989383698
# counter : 4807
# predicted_words : [' vegetarian', ' meat', ' person', ' carniv', ' man']
# 2471
# total_tokens : 388221
# time : 1917.5087463855743
# counter : 4808
# predicted_words : [' man', ' person', ' myth', ' ritual', ' character']
# 2471
# total_tokens : 388285
# time : 1917.8820428848267
# counter : 4809
# predicted_words : [' sweetheart', ' girlfriend', ' lover', ' former', ' beloved']
# 2472
# total_tokens : 388364
# time : 1918.2795042991638
# counter : 4810
# predicted_words : [' magn', ' him', ' a', ' the', ' j']
# 2472
# total_tokens : 388450
# time : 1918.677770614624
# counter : 4811
# predicted_words : [' in', '.', ' to', ' and', ',']
# 2472
# total_tokens : 388532
# time : 1919.0757157802582
# counter : 4812
# predicted_words : [' dirty', ' anything', '.', ',', ' yet']
# 2473
# total_tokens : 388595
# time : 1919.4491658210754
# counter : 4813
# predicted_words : [' sh', ' her', ' a', ' the', ' no']
# 2473
# total_tokens : 388686
# time : 1919.8471584320068
# counter : 4814
# predicted_words : [' rose', ' the', ' b', ' ro', ' Rose']
# 2474
# total_tokens : 388752
# time : 1920.2443594932556
# counter : 4815
# predicted_words : [' am', ' boat', ' first', ' bridge', ' ship']
# 2474
# total_tokens : 388823
# time : 1920.6416945457458
# counter : 4816
# predicted_words : [' lyrics', ' CD', ' album', ' name', ' words']
# 2475
# total_tokens : 388900
# time : 1921.039047718048
# counter : 4817
# predicted_words : [' captain', ' ap', ' boy', ' you', ' sir']
# 2475
# total_tokens : 388994
# time : 1921.438133239746
# counter : 4818
# predicted_words : [' mysteries', ' mystery', ' that', ' to', ' a']
# 2476
# total_tokens : 389063
# time : 1921.8354091644287
# counter : 4819
# predicted_words : [' publisher', ' company', ' publishing', ' firm', ' press']
# 2477
# total_tokens : 389136
# time : 1922.2320611476898
# counter : 4820
# predicted_words : [' corner', ' quiet', ' nice', ' street', ' comer']
# 2478
# total_tokens : 389218
# time : 1922.6299700737
# counter : 4821
# predicted_words : [' people', ' kidn', '.', ' of', ' men']
# 2478
# total_tokens : 389297
# time : 1923.0274798870087
# counter : 4822
# predicted_words : [' ba', ' m', ' w', ' b', ' h']
# 2478
# total_tokens : 389371
# time : 1923.4244005680084
# counter : 4823
# predicted_words : [' games', ' game', ' bar', ' park', ' movies']
# 2479
# total_tokens : 389446
# time : 1923.8231325149536
# counter : 4824
# predicted_words : [' captain', ' young', ' look', ' glare', ' girl']
# 2480
# total_tokens : 389517
# time : 1924.2206737995148
# counter : 4825
# predicted_words : [' money', ' it', ' the', ' his', ' bl']
# 2481
# total_tokens : 389599
# time : 1924.6184887886047
# counter : 4826
# predicted_words : [' tom', ' hw', ' the', ' h', ' to']
# 2481
# total_tokens : 389681
# time : 1925.016678094864
# counter : 4827
# predicted_words : [' engaged', ' getting', ' dating', ' married', ' really']
# 2482
# total_tokens : 389759
# time : 1925.4133789539337
# counter : 4828
# predicted_words : ['.', ' by', ' already', ',', ' long']
# 2483
# total_tokens : 389852
# time : 1925.8116261959076
# counter : 4829
# predicted_words : [' bag', ' the', ' captain', ' i', ' Bag']
# 2483
# total_tokens : 389923
# time : 1926.2090418338776
# counter : 4830
# predicted_words : [' west', ' me', ' frank', ' him', ' her']
# 2483
# total_tokens : 390022
# time : 1926.6239733695984
# counter : 4831
# predicted_words : [' feast', ' show', ' mask', ' costume', ' armor']
# 2484
# total_tokens : 390109
# time : 1927.022864818573
# counter : 4832
# predicted_words : [' this', ' cooking', ' the', ' a', ' that']
# 2485
# total_tokens : 390203
# time : 1927.4219932556152
# counter : 4833
# predicted_words : [' wil', ' the', ' his', ' j', ' d']
# 2485
# total_tokens : 390281
# time : 1927.8192176818848
# counter : 4834
# predicted_words : [' beautiful', '.', ' a', ' pretty', ',']
# 2486
# total_tokens : 390365
# time : 1928.2180597782135
# counter : 4835
# predicted_words : [' jealous', ' trying', '.', ' en', ' even']
# 2487
# total_tokens : 390447
# time : 1928.6155169010162
# counter : 4836
# predicted_words : [' ol', ' iv', ' l', ' j', ' el']
# 2487
# total_tokens : 390516
# time : 1929.0119330883026
# counter : 4837
# predicted_words : [' his', ' re', ' the', ' its', ' Ree']
# 2487
# total_tokens : 390588
# time : 1929.409169435501
# counter : 4838
# predicted_words : [' their', ' a', ' the', ' sweet', ' scent']
# 2487
# total_tokens : 390665
# time : 1929.8075716495514
# counter : 4839
# predicted_words : [' bishop', ' man', ' priest', ' Bishop', ' old']
# 2488
# total_tokens : 390739
# time : 1930.2046918869019
# counter : 4840
# predicted_words : [' say', ' drive', ' answer', ' continue', ' speak']
# 2489
# total_tokens : 390824
# time : 1930.6021711826324
# counter : 4841
# predicted_words : [' filing', ' to', ' anything', ' a', ' n']
# 2490
# total_tokens : 390892
# time : 1930.9993636608124
# counter : 4842
# predicted_words : [' hurt', ' in', ' hurting', ' injured', ' got']
# 2491
# total_tokens : 390970
# time : 1931.396472454071
# counter : 4843
# predicted_words : [' oracle', ' or', ' ar', ' phoenix', ' t']
# 2492
# total_tokens : 391080
# time : 1931.8113770484924
# counter : 4844
# predicted_words : [' dro', ' water', ' drop', ' path', ' trail']
# 2492
# total_tokens : 391153
# time : 1932.2086017131805
# counter : 4845
# predicted_words : [' grill', ' truck', ' car', ' stuff', ' gr']
# 2493
# total_tokens : 391226
# time : 1932.6060500144958
# counter : 4846
# predicted_words : [' remember', ' know', ' work', ' have', ' just']
# 2494
# total_tokens : 391314
# time : 1933.0038216114044
# counter : 4847
# predicted_words : [' graduation', ' party', ' ceremony', ' wedding', ' reception']
# 2495
# total_tokens : 391379
# time : 1933.4010126590729
# counter : 4848
# predicted_words : [' chest', ' other', ' others', ' tree', ' box']
# 2496
# total_tokens : 391463
# time : 1933.799078464508
# counter : 4849
# predicted_words : [' my', " ''", ' but', ' i', ' baby']
# 2496
# total_tokens : 391571
# time : 1934.2141194343567
# counter : 4850
# predicted_words : [' any', ' adventures', ' many', ' a', ' much']
# 2497
# total_tokens : 391662
# time : 1934.611941576004
# counter : 4851
# predicted_words : [' matt', ' the', ' him', ' her', ' mat']
# 2498
# total_tokens : 391739
# time : 1935.009660243988
# counter : 4852
# predicted_words : [' bob', ' a', ' his', ' the', ' no']
# 2499
# total_tokens : 391822
# time : 1935.40766787529
# counter : 4853
# predicted_words : [' bed', ' grass', ' floor', ' couch', ' sand']
# 2499
# total_tokens : 391890
# time : 1935.8052580356598
# counter : 4854
# predicted_words : [' stick', ' walking', ' cane', ' aid', ' hand']
# 2500
# total_tokens : 391981
# time : 1936.2028245925903
# counter : 4855
# predicted_words : [' eng', ' nor', ' sc', ' the', ' ire']
# 2500
# total_tokens : 392062
# time : 1936.6007483005524
# counter : 4856
# predicted_words : [' husband', ' good', ' family', ' father', ' man']
# 2501
# total_tokens : 392126
# time : 1936.974101781845
# counter : 4857
# predicted_words : [' t', " ''", ' son', ' my', ' kid']
# 2501
# total_tokens : 392216
# time : 1937.3717403411865
# counter : 4858
# predicted_words : [' to', ' awake', ' conscious', ' able', ' revived']
# 2501
# total_tokens : 392294
# time : 1937.769050359726
# counter : 4859
# predicted_words : [' his', ' dara', ' j', ' the', ' dar']
# 2502
# total_tokens : 392376
# time : 1938.1665635108948
# counter : 4860
# predicted_words : [' couch', ' chairs', ' sofa', ' set', ' sofas']
# 2503
# total_tokens : 392470
# time : 1938.5653932094574
# counter : 4861
# predicted_words : [' rope', ' packages', ' ropes', ' heavy', ' four']
# 2504
# total_tokens : 392560
# time : 1938.9641888141632
# counter : 4862
# predicted_words : [" ''", ' "', ' ``', ' i', ' about']
# 2504
# total_tokens : 392635
# time : 1939.36248421669
# counter : 4863
# predicted_words : [' tower', ' base', ' l', ' sea', ' foot']
# 2505
# total_tokens : 392721
# time : 1939.761400461197
# counter : 4864
# predicted_words : ['?', ' if', ' they', " '", ',']
# 2505
# total_tokens : 392821
# time : 1940.1761996746063
# counter : 4865
# predicted_words : [' singing', ' starting', ' bel', ' letting', ' beginning']
# 2506
# total_tokens : 392884
# time : 1940.5499470233917
# counter : 4866
# predicted_words : [' jul', ' her', ' j', ' the', ' them']
# 2506
# total_tokens : 392963
# time : 1940.947366476059
# counter : 4867
# predicted_words : [' division', '?', ' or', ',', '.']
# 2507
# total_tokens : 393037
# time : 1941.344831943512
# counter : 4868
# predicted_words : [' me', ' the', ' lo', ' d', ' his']
# 2507
# total_tokens : 393120
# time : 1941.7439019680023
# counter : 4869
# predicted_words : ['.', ',', ' too', ' as', ' and']
# 2508
# total_tokens : 393195
# time : 1942.1416881084442
# Model evaluation finsihed !
# Top-5 Accuracy: 51.51%
# Speed: 202.45 Tokens/s
# Inference Time : 2.5075404235321934
# Number of parameters: 394177536.00
# Results :
# Top-5 Accuracy: [0.5150955021565004]
# Speed: [202.45428271678458]
# Number of parameters: [394177536]
